# %% [markdown]
# # Encontrar os locais ideais para as instalações de fabricação para atender à demanda dos clientes e reduzir custos de produção

# %%
import pandas as pd
from pulp import * # modelador LP (promgramação linear)
